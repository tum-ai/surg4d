# %%
import numpy as np
import matplotlib.pyplot as plt

f = np.load('data/cholecseg8k/preprocessed/video01_00080/language_features_default-language_features_dim3/000010_f.npy')
s = np.load('data/cholecseg8k/preprocessed/video01_00080/language_features_default-language_features_dim3/000010_s.npy')

s = np.asarray(s[0], dtype=np.int16)

feat = f[s] / 2. + 1.
plt.imshow(feat)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.5303891..1.4601828].
