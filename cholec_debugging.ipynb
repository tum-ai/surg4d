# %%
import numpy as np
from plyfile import PlyData
from pathlib import Path
import matplotlib.pyplot as plt

# %%
ply_path = Path('output/cholecseg8k/video27/video27_00480/rgb/point_cloud/fine-base_iteration_10000/point_cloud.ply')

# %%
pcd = PlyData.read(ply_path)['vertex']

# %%
plt.hist(pcd['f_dc_0'])
# Out:
# (array([2.9130e+03, 1.6140e+04, 2.0848e+04, 2.5661e+04, 2.0442e+04,
#         1.2251e+04, 5.6220e+03, 1.2780e+03, 8.2000e+01, 1.1000e+01]),
#  array([-1.92572069, -1.35904241, -0.792364  , -0.2256856 ,  0.34099269,
#          0.90767097,  1.4743495 ,  2.04102778,  2.60770607,  3.17438459,
#          3.74106264]),
#  <BarContainer object of 10 artists>)
